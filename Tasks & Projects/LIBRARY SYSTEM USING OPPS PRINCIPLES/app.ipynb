# %% [markdown]
# # 📚 Simple Library System using OOP

# %%
# Book Class
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author
        self.is_borrowed = False  # Initially, book is available


# Library Class

class Library:
    def __init__(self):
        self.books = []  # Empty list to store books

    def add_book(self, book):
        self.books.append(book)
        print(f"Book '{book.title}' added to the library.")

    def show_books(self):
        print("\nBooks in Library:")
        for book in self.books:
            status = "Borrowed" if book.is_borrowed else "Available"
            print(f"- {book.title} by {book.author} ({status})")

    def borrow_book(self, title):
        for book in self.books:
            if book.title.lower() == title.lower():
                if not book.is_borrowed:
                    book.is_borrowed = True
                    print(f"You borrowed '{book.title}'.")
                else:
                    print(f"Sorry, '{book.title}' is already borrowed.")
                return
        print("Book not found in library.")

    def return_book(self, title):
        for book in self.books:
            if book.title.lower() == title.lower():
                if book.is_borrowed:
                    book.is_borrowed = False
                    print(f"You returned '{book.title}'.")
                else:
                    print(f"'{book.title}' was not borrowed.")
                return
        print("Book not found in library.")
        


# Main Program
library = Library()

# Add some books
book1 = Book("Python Basics", "John Smith")
book2 = Book("Learn Java", "Robert K")
book3 = Book("HTML and CSS", "Angela Yu")

library.add_book(book1)
library.add_book(book2)
library.add_book(book3)

# Show all books
library.show_books()

# Borrow a book
library.borrow_book("Python Basics")

# Show again
library.show_books()

# Return a book
library.return_book("Python Basics")

# Show again
library.show_books()
# Out:
# Book 'Python Basics' added to the library.
# Book 'Learn Java' added to the library.
# Book 'HTML and CSS' added to the library.
#
# Books in Library:
# - Python Basics by John Smith (Available)
# - Learn Java by Robert K (Available)
# - HTML and CSS by Angela Yu (Available)
# You borrowed 'Python Basics'.
#
# Books in Library:
# - Python Basics by John Smith (Borrowed)
# - Learn Java by Robert K (Available)
# - HTML and CSS by Angela Yu (Available)
# You returned 'Python Basics'.
#
# Books in Library:
# - Python Basics by John Smith (Available)
# - Learn Java by Robert K (Available)
# - HTML and CSS by Angela Yu (Available)
